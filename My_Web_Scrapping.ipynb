# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
data=requests.get("https://www.newegg.com/p/pl?N=100007709%20601194948%20601202919%20601203901%20601203927%20601205646%20601294835%20601295933%20601296377%20601301599%20601305993%20601321572%20601323902%20601326374%20601331379%20601341679&cm_sp=Cat_video-Cards_1-_-Visnav-_-Gaming-Video-Cards_1")

# %%
data=data.content

# %%
soup=BeautifulSoup(data)

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
# <html lang="en-us">
# <head>
# <title>Radeon RX 5000 Series, GeForce GTX 16 Series, TITAN, Radeon RX 590, GeForce RTX 20 Series, GeForce GTX 1070 Ti, Radeon Vega Series, Radeon RX 580, Ge... - Newegg.com</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="always" name="referrer"/>
# <meta content="Newegg.com - Radeon RX 5000 Series, GeForce GTX 16 Series, TITAN, Radeon RX 590, GeForce RTX 20 Series, GeForce GTX 1070 Ti, Radeon Vega Series, Radeon RX 580, Ge..." name="keywords"/>
# <meta content="Newegg.com offers the best prices on computer products, laptop computers, LED LCD TVs, digital cameras, electronics, unlocked phones, office supplies, and more with fast shipping and top-rated customer service. Newegg shopping upgraded ™" name="description"/>
# <meta content="https://c1.neweggimages.com/WebResource/Themes/2005/Nest/logo_424x210.png" property="og:image"/>
# ...

# %%
containers=soup.find_all("div",{"class":"item-container      "})

# %%
containers
# Out:
# []
